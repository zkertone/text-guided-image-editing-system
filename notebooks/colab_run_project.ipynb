# %% [markdown]
# # Colab Launcher for Text-Guided Image Editing System
#
# 这个 notebook 仅用于在 Google Colab 中启动当前项目，不重写项目业务逻辑。
#
# 建议按顺序逐段运行。

# %% [markdown]
# ## 1. 获取项目代码
#
# ### 公开仓库
#
# 如果你的 GitHub 仓库是公开的，可以直接使用 `git clone`。
#
# ### 私有仓库
#
# 如果仓库是私有的，常见做法有两种：
#
# - 方式一：先在 Colab 中执行 `from google.colab import drive` 并挂载 Google Drive，再把项目代码提前上传到 Drive 中使用
# - 方式二：使用带访问权限的 GitHub 令牌克隆私有仓库
#
# 下面代码默认示例为公开仓库。你只需要把仓库地址改成自己的即可。

# %%
REPO_URL = "https://github.com/zkertone/text-guided-image-editing-system.git"
PROJECT_DIR = "/content/text-guided-image-editing-system"

# %%
# !rm -rf "$PROJECT_DIR"
# !git clone "$REPO_URL" "$PROJECT_DIR"

# %% [markdown]
# 如果你使用私有仓库，可以参考下面这种方式，把 `YOUR_GITHUB_TOKEN` 和仓库地址替换成你自己的信息。
#
# 注意：不要把真实令牌提交到 GitHub。

# %%
# PRIVATE_REPO_URL = "https://YOUR_GITHUB_TOKEN@github.com/your-name/your-private-repo.git"
# PROJECT_DIR = "/content/text-guided-image-editing-system"
# !rm -rf "$PROJECT_DIR"
# !git clone "$PRIVATE_REPO_URL" "$PROJECT_DIR"

# %% [markdown]
# ## 2. 进入项目目录

# %%
# %cd /content/text-guided-image-editing-system

# %% [markdown]
# ## 3. 安装依赖
#
# 这里直接使用项目中的 `requirements.txt`。

# %%
# !python -m pip install --upgrade pip
# !pip install -r requirements.txt

# %% [markdown]
# ## 4. 设置 Colab 运行环境
#
# 为了便于在 Colab 中访问 Gradio 页面，这里设置：
#
# - `GRADIO_SERVER_NAME=0.0.0.0`
# - `GRADIO_SERVER_PORT=7860`
# - `GRADIO_SHARE=true`

# %%
import os

os.environ["GRADIO_SERVER_NAME"] = "0.0.0.0"
os.environ["GRADIO_SERVER_PORT"] = "7860"
os.environ["GRADIO_SHARE"] = "true"

print("GRADIO_SERVER_NAME =", os.environ["GRADIO_SERVER_NAME"])
print("GRADIO_SERVER_PORT =", os.environ["GRADIO_SERVER_PORT"])
print("GRADIO_SHARE =", os.environ["GRADIO_SHARE"])

# %% [markdown]
# ## 5. 启动项目
#
# 下面命令会直接调用项目已有入口：`python -m app.main`。

# %%
# !python -m app.main
